# %% [markdown]
# *This is similar to LinearRegression*

# %%
learning_rate = 0.01
w,b=0,0
g_w = 0
g_b = 0.167 #g_w , g_b is found in GradientW
w_update = w - learning_rate*g_w    
b_update = b - learning_rate*g_b
print(w_update,b_update)
# Out:
# 0.0 -0.00167

# %% [markdown]
# **We will calculate z, g_w , g_b , w_update , b_update just like in previous problem**

# %%
X = [1, 2, 3]
y = [0, 0, 1]
p = []
for i in X:
    sigmoid = w_update*i + b
    p.append(sigmoid)
g_w = 0
g_b = 0
for i in range(len(X)):
    g_w +=   X[i]*(p[i]-y[i])
    g_b += p[i] - y[i]
g_w = g_w/len(X)
g_b = g_b/len(X)
w_update1 = w_update - learning_rate*g_w
b_update1 = b_update - learning_rate*g_b
print(w_update1,b_update1)
# Out:
# 0.01 0.001663333333333333

# %% [markdown]
# **After the second update , w and b =**
