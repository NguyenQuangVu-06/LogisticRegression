# %%
y_true = [0,0,0,1,1,1,1,0]
y_pred = [0,1,0,1,0,1,1,0]
#False Positive is when initial data (y_true) = 0 but predictive data = 1
#False Negative is when initial data (y_true) = 1 but predictive data = 0
#True Positive is when initial data (y_true) = 1 then predictive data = 1
#True Negative is when initial data (y_true) = 0 then predictive data = 0
FP = 1
FN = 1
TP = 3
TN = 3

# %% [markdown]
# **Based the total of FP,FN,TP,TN above , we will calculate  Precision , Recall , F1 , Accuracy**

# %% [markdown]
# **Precision =  TP / (TP + FP)**

# %% [markdown]
# **Recall = TP / TP + FN**

# %% [markdown]
# **Accuracy = total number of correct predictive / total number of incorrect predictive**

# %% [markdown]
# **F1 = (2*Precision*Recall)/(Precision+Recall)**

# %%
Recall = 0.75
Precision = 0.75
Accuracy = 0.75
F1 = 0.75
